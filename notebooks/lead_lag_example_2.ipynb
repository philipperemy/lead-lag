# %%
# %matplotlib inline
import lead_lag
import pandas as pd
from matplotlib import pyplot as plt

# %%
def plot_time_series(bitflyer: pd.Series, btcbox: pd.Series) -> None:
    d = pd.DataFrame(data={'bitflyer': bitflyer['last'], 'btcbox': btcbox['last']}).ffill().dropna()
    slice_d = d['2018-08-12 12:05:30':'2018-08-12 12:08:25']
    slice_d['bitflyer'].plot(color='blue', linewidth=2, x_compat=True, legend='b')
    slice_d['btcbox'].plot(color='limegreen', linewidth=2, x_compat=True, legend='b')
    plt.grid(True)
    plt.title('Bitflyer vs Btcbox (2018, on 1s data)')
    plt.xlabel('Time')
    plt.ylabel('Bitcoin price (Yen)')
    plt.show()

# %%
bitflyer = pd.read_csv('../data/bitflyerJPY_2018-08-12_small.csv', parse_dates=True, index_col=0)
btcbox = pd.read_csv('../data/btcboxJPY_2018-08-12_small.csv', parse_dates=True, index_col=0)

# %%
plot_time_series(bitflyer, btcbox)

# %%
ll = lead_lag.LeadLag(
    ts1=bitflyer['last'],
    ts2=btcbox['last'],
    max_lag=30,  # [-X seconds, +X seconds]
    verbose=True,
    min_precision=0.1  # in seconds.
)
# Out:
# Precision = 100.0 ms.

# %%
print('Running inference...')
ll.run_inference()
# Out:
# Running inference...
# Running slow_inference() on (-300:300) with 1 thread.
# Lag=-300, contrast=0.01639, elapsed=15.22ms.
# Lag=-299, contrast=0.01817, elapsed=15.44ms.
# Lag=-298, contrast=0.01817, elapsed=15.12ms.
# Lag=-297, contrast=0.01817, elapsed=14.85ms.
# Lag=-296, contrast=0.01817, elapsed=14.96ms.
# Lag=-295, contrast=0.01817, elapsed=14.14ms.
# Lag=-294, contrast=0.01817, elapsed=14.18ms.
# Lag=-293, contrast=0.01817, elapsed=14.44ms.
# Lag=-292, contrast=0.01817, elapsed=14.42ms.
# Lag=-291, contrast=0.01817, elapsed=14.12ms.
# Lag=-290, contrast=0.01873, elapsed=14.11ms.
# Lag=-289, contrast=0.01600, elapsed=14.07ms.
# Lag=-288, contrast=0.01600, elapsed=14.31ms.
# Lag=-287, contrast=0.01600, elapsed=14.52ms.
# Lag=-286, contrast=0.01600, elapsed=14.14ms.
# Lag=-285, contrast=0.01600, elapsed=13.91ms.
# Lag=-284, contrast=0.01600, elapsed=14.08ms.
# Lag=-283, contrast=0.01600, elapsed=14.68ms.
# Lag=-282, contrast=0.01600, elapsed=14.76ms.
# Lag=-281, contrast=0.01600, elapsed=14.18ms.
# Lag=-280, contrast=0.00234, elapsed=14.21ms.
# Lag=-279, contrast=0.01730, elapsed=14.24ms.
# Lag=-278, contrast=0.01730, elapsed=14.34ms.
# Lag=-277, contrast=0.01730, elapsed=14.30ms.
# Lag=-276, contrast=0.01730, elapsed=14.48ms.
# Lag=-275, contrast=0.01730, elapsed=14.46ms.
# Lag=-274, contrast=0.01730, elapsed=14.12ms.
# Lag=-273, contrast=0.01730, elapsed=14.09ms.
# Lag=-272, contrast=0.01730, elapsed=14.15ms.
# Lag=-271, contrast=0.01730, elapsed=14.16ms.
# Lag=-270, contrast=0.03848, elapsed=14.03ms.
# Lag=-269, contrast=0.03162, elapsed=15.64ms.
# Lag=-268, contrast=0.03162, elapsed=15.84ms.
# Lag=-267, contrast=0.03162, elapsed=16.10ms.
# Lag=-266, contrast=0.03162, elapsed=16.32ms.
# Lag=-265, contrast=0.03162, elapsed=15.86ms.
# Lag=-264, contrast=0.03162, elapsed=15.36ms.
# Lag=-263, contrast=0.03162, elapsed=15.52ms.
# Lag=-262, contrast=0.03162, elapsed=14.48ms.
# Lag=-261, contrast=0.03162, elapsed=15.52ms.
# Lag=-260, contrast=0.01696, elapsed=14.25ms.
# Lag=-259, contrast=0.00137, elapsed=14.16ms.
# Lag=-258, contrast=0.00137, elapsed=14.09ms.
# Lag=-257, contrast=0.00137, elapsed=14.17ms.
# Lag=-256, contrast=0.00137, elapsed=14.32ms.
# Lag=-255, contrast=0.00137, elapsed=14.21ms.
# Lag=-254, contrast=0.00137, elapsed=14.18ms.
# Lag=-253, contrast=0.00137, elapsed=14.10ms.
# Lag=-252, contrast=0.00137, elapsed=14.52ms.
# Lag=-251, contrast=0.00137, elapsed=15.52ms.
# Lag=-250, contrast=0.01132, elapsed=14.65ms.
# Lag=-249, contrast=0.00209, elapsed=14.49ms.
# Lag=-248, contrast=0.00209, elapsed=14.34ms.
# Lag=-247, contrast=0.00209, elapsed=14.41ms.
# Lag=-246, contrast=0.00209, elapsed=14.93ms.
# Lag=-245, contrast=0.00209, elapsed=14.83ms.
# Lag=-244, contrast=0.00209, elapsed=14.86ms.
# Lag=-243, contrast=0.00209, elapsed=15.25ms.
# Lag=-242, contrast=0.00209, elapsed=14.36ms.
# Lag=-241, contrast=0.00209, elapsed=14.22ms.
# Lag=-240, contrast=0.01038, elapsed=14.62ms.
# Lag=-239, contrast=0.01194, elapsed=14.26ms.
# Lag=-238, contrast=0.01194, elapsed=14.31ms.
# Lag=-237, contrast=0.01194, elapsed=14.33ms.
# Lag=-236, contrast=0.01194, elapsed=14.17ms.
# Lag=-235, contrast=0.01194, elapsed=13.93ms.
# Lag=-234, contrast=0.01194, elapsed=14.83ms.
# Lag=-233, contrast=0.01194, elapsed=14.34ms.
# Lag=-232, contrast=0.01194, elapsed=14.19ms.
# Lag=-231, contrast=0.01194, elapsed=14.55ms.
# Lag=-230, contrast=0.00113, elapsed=15.17ms.
# Lag=-229, contrast=0.00393, elapsed=15.72ms.
# Lag=-228, contrast=0.00393, elapsed=14.85ms.
# Lag=-227, contrast=0.00393, elapsed=15.39ms.
# Lag=-226, contrast=0.00393, elapsed=14.46ms.
# Lag=-225, contrast=0.00393, elapsed=14.43ms.
# Lag=-224, contrast=0.00393, elapsed=14.28ms.
# Lag=-223, contrast=0.00393, elapsed=14.47ms.
# Lag=-222, contrast=0.00393, elapsed=14.33ms.
# Lag=-221, contrast=0.00393, elapsed=14.25ms.
# Lag=-220, contrast=0.01678, elapsed=14.13ms.
# Lag=-219, contrast=0.01392, elapsed=14.46ms.
# Lag=-218, contrast=0.01392, elapsed=14.63ms.
# Lag=-217, contrast=0.01392, elapsed=14.34ms.
# Lag=-216, contrast=0.01392, elapsed=14.22ms.
# Lag=-215, contrast=0.01392, elapsed=15.46ms.
# Lag=-214, contrast=0.01392, elapsed=14.30ms.
# Lag=-213, contrast=0.01392, elapsed=14.34ms.
# Lag=-212, contrast=0.01392, elapsed=16.23ms.
# Lag=-211, contrast=0.01392, elapsed=17.15ms.
# Lag=-210, contrast=0.04392, elapsed=14.77ms.
# Lag=-209, contrast=0.02683, elapsed=14.27ms.
# Lag=-208, contrast=0.02683, elapsed=14.45ms.
# Lag=-207, contrast=0.02683, elapsed=14.90ms.
# Lag=-206, contrast=0.02683, elapsed=14.50ms.
# Lag=-205, contrast=0.02683, elapsed=14.28ms.
# Lag=-204, contrast=0.02683, elapsed=14.25ms.
# Lag=-203, contrast=0.02683, elapsed=14.22ms.
# Lag=-202, contrast=0.02683, elapsed=14.25ms.
# Lag=-201, contrast=0.02683, elapsed=14.27ms.
# Lag=-200, contrast=0.00720, elapsed=14.14ms.
# Lag=-199, contrast=0.01117, elapsed=14.14ms.
# Lag=-198, contrast=0.01117, elapsed=14.34ms.
# Lag=-197, contrast=0.01117, elapsed=14.59ms.
# Lag=-196, contrast=0.01117, elapsed=15.39ms.
# Lag=-195, contrast=0.01117, elapsed=15.23ms.
# Lag=-194, contrast=0.01117, elapsed=15.69ms.
# Lag=-193, contrast=0.01117, elapsed=14.93ms.
# Lag=-192, contrast=0.01117, elapsed=14.54ms.
# Lag=-191, contrast=0.01117, elapsed=15.46ms.
# Lag=-190, contrast=0.02096, elapsed=14.33ms.
# Lag=-189, contrast=0.02334, elapsed=14.63ms.
# Lag=-188, contrast=0.02334, elapsed=14.23ms.
# Lag=-187, contrast=0.02334, elapsed=14.17ms.
# Lag=-186, contrast=0.02334, elapsed=14.40ms.
# Lag=-185, contrast=0.02334, elapsed=15.30ms.
# Lag=-184, contrast=0.02334, elapsed=14.32ms.
# Lag=-183, contrast=0.02334, elapsed=14.19ms.
# Lag=-182, contrast=0.02334, elapsed=14.53ms.
# Lag=-181, contrast=0.02334, elapsed=14.47ms.
# Lag=-180, contrast=0.00901, elapsed=14.37ms.
# Lag=-179, contrast=0.01946, elapsed=14.11ms.
# Lag=-178, contrast=0.01946, elapsed=14.25ms.
# Lag=-177, contrast=0.01946, elapsed=14.41ms.
# Lag=-176, contrast=0.01946, elapsed=14.27ms.
# Lag=-175, contrast=0.01946, elapsed=14.27ms.
# Lag=-174, contrast=0.01946, elapsed=15.32ms.
# Lag=-173, contrast=0.01946, elapsed=14.86ms.
# Lag=-172, contrast=0.01946, elapsed=14.31ms.
# Lag=-171, contrast=0.01946, elapsed=15.00ms.
# Lag=-170, contrast=0.01335, elapsed=14.73ms.
# Lag=-169, contrast=0.00778, elapsed=14.26ms.
# Lag=-168, contrast=0.00778, elapsed=14.19ms.
# Lag=-167, contrast=0.00778, elapsed=14.22ms.
# Lag=-166, contrast=0.00778, elapsed=14.25ms.
# Lag=-165, contrast=0.00778, elapsed=14.19ms.
# Lag=-164, contrast=0.00778, elapsed=14.21ms.
# Lag=-163, contrast=0.00778, elapsed=14.23ms.
# Lag=-162, contrast=0.00778, elapsed=14.18ms.
# Lag=-161, contrast=0.00778, elapsed=14.29ms.
# Lag=-160, contrast=0.00359, elapsed=14.35ms.
# Lag=-159, contrast=0.00147, elapsed=14.51ms.
# Lag=-158, contrast=0.00147, elapsed=14.56ms.
# Lag=-157, contrast=0.00147, elapsed=14.18ms.
# Lag=-156, contrast=0.00147, elapsed=15.35ms.
# Lag=-155, contrast=0.00147, elapsed=15.16ms.
# Lag=-154, contrast=0.00147, elapsed=14.47ms.
# Lag=-153, contrast=0.00147, elapsed=14.60ms.
# Lag=-152, contrast=0.00147, elapsed=14.57ms.
# Lag=-151, contrast=0.00147, elapsed=14.48ms.
# Lag=-150, contrast=0.00110, elapsed=14.59ms.
# Lag=-149, contrast=0.00377, elapsed=14.40ms.
# Lag=-148, contrast=0.00377, elapsed=14.39ms.
# Lag=-147, contrast=0.00377, elapsed=14.20ms.
# Lag=-146, contrast=0.00377, elapsed=14.30ms.
# Lag=-145, contrast=0.00377, elapsed=14.25ms.
# Lag=-144, contrast=0.00377, elapsed=14.34ms.
# Lag=-143, contrast=0.00377, elapsed=14.38ms.
# Lag=-142, contrast=0.00377, elapsed=15.16ms.
# Lag=-141, contrast=0.00377, elapsed=14.27ms.
# Lag=-140, contrast=0.01432, elapsed=13.98ms.
# Lag=-139, contrast=0.02476, elapsed=14.17ms.
# Lag=-138, contrast=0.02476, elapsed=14.09ms.
# Lag=-137, contrast=0.02476, elapsed=15.29ms.
# Lag=-136, contrast=0.02476, elapsed=14.91ms.
# Lag=-135, contrast=0.02476, elapsed=14.59ms.
# Lag=-134, contrast=0.02476, elapsed=14.28ms.
# Lag=-133, contrast=0.02476, elapsed=14.20ms.
# Lag=-132, contrast=0.02476, elapsed=14.20ms.
# Lag=-131, contrast=0.02476, elapsed=14.33ms.
# Lag=-130, contrast=0.02374, elapsed=14.23ms.
# Lag=-129, contrast=0.01434, elapsed=14.21ms.
# Lag=-128, contrast=0.01434, elapsed=14.18ms.
# Lag=-127, contrast=0.01434, elapsed=14.28ms.
# Lag=-126, contrast=0.01434, elapsed=14.24ms.
# Lag=-125, contrast=0.01434, elapsed=14.23ms.
# Lag=-124, contrast=0.01434, elapsed=14.25ms.
# Lag=-123, contrast=0.01434, elapsed=14.40ms.
# Lag=-122, contrast=0.01434, elapsed=15.07ms.
# Lag=-121, contrast=0.01434, elapsed=14.71ms.
# Lag=-120, contrast=0.00949, elapsed=14.55ms.
# Lag=-119, contrast=0.00858, elapsed=15.57ms.
# Lag=-118, contrast=0.00858, elapsed=14.45ms.
# Lag=-117, contrast=0.00858, elapsed=14.43ms.
# Lag=-116, contrast=0.00858, elapsed=15.46ms.
# Lag=-115, contrast=0.00858, elapsed=14.48ms.
# Lag=-114, contrast=0.00858, elapsed=14.47ms.
# Lag=-113, contrast=0.00858, elapsed=14.25ms.
# Lag=-112, contrast=0.00858, elapsed=14.23ms.
# Lag=-111, contrast=0.00858, elapsed=14.17ms.
# Lag=-110, contrast=0.02002, elapsed=14.16ms.
# Lag=-109, contrast=0.01622, elapsed=14.32ms.
# Lag=-108, contrast=0.01622, elapsed=14.44ms.
# Lag=-107, contrast=0.01622, elapsed=14.21ms.
# Lag=-106, contrast=0.01622, elapsed=15.47ms.
# Lag=-105, contrast=0.01622, elapsed=15.29ms.
# Lag=-104, contrast=0.01622, elapsed=14.35ms.
# Lag=-103, contrast=0.01622, elapsed=14.25ms.
# Lag=-102, contrast=0.01622, elapsed=14.38ms.
# Lag=-101, contrast=0.01622, elapsed=14.29ms.
# Lag=-100, contrast=0.01506, elapsed=14.37ms.
# Lag=-99, contrast=0.02313, elapsed=15.03ms.
# Lag=-98, contrast=0.02313, elapsed=14.98ms.
# Lag=-97, contrast=0.02313, elapsed=15.30ms.
# Lag=-96, contrast=0.02313, elapsed=14.40ms.
# Lag=-95, contrast=0.02313, elapsed=14.25ms.
# Lag=-94, contrast=0.02313, elapsed=14.32ms.
# Lag=-93, contrast=0.02313, elapsed=14.20ms.
# Lag=-92, contrast=0.02313, elapsed=15.55ms.
# Lag=-91, contrast=0.02313, elapsed=14.89ms.
# Lag=-90, contrast=0.02579, elapsed=14.64ms.
# Lag=-89, contrast=0.02779, elapsed=14.37ms.
# Lag=-88, contrast=0.02779, elapsed=14.27ms.
# Lag=-87, contrast=0.02779, elapsed=14.22ms.
# Lag=-86, contrast=0.02779, elapsed=14.18ms.
# Lag=-85, contrast=0.02779, elapsed=14.16ms.
# Lag=-84, contrast=0.02779, elapsed=14.17ms.
# Lag=-83, contrast=0.02779, elapsed=14.23ms.
# Lag=-82, contrast=0.02779, elapsed=14.37ms.
# Lag=-81, contrast=0.02779, elapsed=14.28ms.
# Lag=-80, contrast=0.02420, elapsed=14.16ms.
# Lag=-79, contrast=0.03995, elapsed=14.23ms.
# Lag=-78, contrast=0.03995, elapsed=14.31ms.
# Lag=-77, contrast=0.03995, elapsed=14.43ms.
# Lag=-76, contrast=0.03995, elapsed=14.22ms.
# Lag=-75, contrast=0.03995, elapsed=14.04ms.
# Lag=-74, contrast=0.03995, elapsed=14.24ms.
# Lag=-73, contrast=0.03995, elapsed=15.22ms.
# Lag=-72, contrast=0.03995, elapsed=15.90ms.
# Lag=-71, contrast=0.03995, elapsed=15.38ms.
# Lag=-70, contrast=0.04241, elapsed=15.22ms.
# Lag=-69, contrast=0.03364, elapsed=15.16ms.
# Lag=-68, contrast=0.03364, elapsed=15.09ms.
# Lag=-67, contrast=0.03364, elapsed=15.10ms.
# Lag=-66, contrast=0.03364, elapsed=15.30ms.
# Lag=-65, contrast=0.03364, elapsed=15.22ms.
# Lag=-64, contrast=0.03364, elapsed=14.62ms.
# Lag=-63, contrast=0.03364, elapsed=14.42ms.
# Lag=-62, contrast=0.03364, elapsed=14.25ms.
# Lag=-61, contrast=0.03364, elapsed=14.21ms.
# Lag=-60, contrast=0.02032, elapsed=14.58ms.
# Lag=-59, contrast=0.02188, elapsed=14.48ms.
# Lag=-58, contrast=0.02188, elapsed=14.00ms.
# Lag=-57, contrast=0.02188, elapsed=14.99ms.
# Lag=-56, contrast=0.02188, elapsed=14.72ms.
# Lag=-55, contrast=0.02188, elapsed=15.55ms.
# Lag=-54, contrast=0.02188, elapsed=14.41ms.
# Lag=-53, contrast=0.02188, elapsed=14.17ms.
# Lag=-52, contrast=0.02188, elapsed=14.16ms.
# Lag=-51, contrast=0.02188, elapsed=14.16ms.
# Lag=-50, contrast=0.01791, elapsed=14.11ms.
# Lag=-49, contrast=0.03213, elapsed=14.16ms.
# Lag=-48, contrast=0.03213, elapsed=14.14ms.
# Lag=-47, contrast=0.03213, elapsed=14.14ms.
# Lag=-46, contrast=0.03213, elapsed=14.18ms.
# Lag=-45, contrast=0.03213, elapsed=14.19ms.
# Lag=-44, contrast=0.03213, elapsed=14.19ms.
# Lag=-43, contrast=0.03213, elapsed=14.47ms.
# Lag=-42, contrast=0.03213, elapsed=14.19ms.
# Lag=-41, contrast=0.03213, elapsed=13.93ms.
# Lag=-40, contrast=0.04115, elapsed=14.05ms.
# Lag=-39, contrast=0.04715, elapsed=14.58ms.
# Lag=-38, contrast=0.04715, elapsed=14.96ms.
# Lag=-37, contrast=0.04715, elapsed=14.60ms.
# Lag=-36, contrast=0.04715, elapsed=14.57ms.
# Lag=-35, contrast=0.04715, elapsed=14.25ms.
# Lag=-34, contrast=0.04715, elapsed=14.23ms.
# Lag=-33, contrast=0.04715, elapsed=14.26ms.
# Lag=-32, contrast=0.04715, elapsed=14.54ms.
# Lag=-31, contrast=0.04715, elapsed=14.50ms.
# Lag=-30, contrast=0.01799, elapsed=14.50ms.
# Lag=-29, contrast=0.03414, elapsed=14.35ms.
# Lag=-28, contrast=0.03414, elapsed=14.23ms.
# Lag=-27, contrast=0.03414, elapsed=14.37ms.
# Lag=-26, contrast=0.03414, elapsed=14.32ms.
# Lag=-25, contrast=0.03414, elapsed=15.61ms.
# Lag=-24, contrast=0.03414, elapsed=15.07ms.
# Lag=-23, contrast=0.03414, elapsed=14.27ms.
# Lag=-22, contrast=0.03414, elapsed=14.14ms.
# Lag=-21, contrast=0.03414, elapsed=15.21ms.
# Lag=-20, contrast=0.04666, elapsed=14.55ms.
# Lag=-19, contrast=0.04730, elapsed=14.96ms.
# Lag=-18, contrast=0.04730, elapsed=14.32ms.
# Lag=-17, contrast=0.04730, elapsed=14.22ms.
# Lag=-16, contrast=0.04730, elapsed=14.19ms.
# Lag=-15, contrast=0.04730, elapsed=14.19ms.
# Lag=-14, contrast=0.04730, elapsed=14.20ms.
# Lag=-13, contrast=0.04730, elapsed=14.50ms.
# Lag=-12, contrast=0.04730, elapsed=14.27ms.
# Lag=-11, contrast=0.04730, elapsed=14.17ms.
# Lag=-10, contrast=0.03438, elapsed=14.12ms.
# Lag=-9, contrast=0.03633, elapsed=14.16ms.
# Lag=-8, contrast=0.03633, elapsed=14.16ms.
# Lag=-7, contrast=0.03633, elapsed=14.18ms.
# Lag=-6, contrast=0.03633, elapsed=14.32ms.
# Lag=-5, contrast=0.03633, elapsed=14.33ms.
# Lag=-4, contrast=0.03633, elapsed=14.12ms.
# Lag=-3, contrast=0.03633, elapsed=14.08ms.
# Lag=-2, contrast=0.03633, elapsed=14.67ms.
# Lag=-1, contrast=0.03633, elapsed=15.28ms.
# Lag=0, contrast=0.02917, elapsed=14.89ms.
# Lag=1, contrast=0.02998, elapsed=14.62ms.
# Lag=2, contrast=0.02998, elapsed=14.25ms.
# Lag=3, contrast=0.02998, elapsed=14.24ms.
# Lag=4, contrast=0.02998, elapsed=14.22ms.
# Lag=5, contrast=0.02998, elapsed=14.24ms.
# Lag=6, contrast=0.02998, elapsed=14.18ms.
# Lag=7, contrast=0.02998, elapsed=14.18ms.
# Lag=8, contrast=0.02998, elapsed=14.14ms.
# Lag=9, contrast=0.02998, elapsed=14.16ms.
# Lag=10, contrast=0.03762, elapsed=14.10ms.
# Lag=11, contrast=0.07104, elapsed=14.16ms.
# Lag=12, contrast=0.07104, elapsed=14.30ms.
# Lag=13, contrast=0.07104, elapsed=15.19ms.
# Lag=14, contrast=0.07104, elapsed=15.38ms.
# Lag=15, contrast=0.07104, elapsed=14.53ms.
# Lag=16, contrast=0.07104, elapsed=15.04ms.
# Lag=17, contrast=0.07104, elapsed=14.36ms.
# Lag=18, contrast=0.07104, elapsed=14.21ms.
# Lag=19, contrast=0.07104, elapsed=14.19ms.
# Lag=20, contrast=0.07868, elapsed=14.19ms.
# Lag=21, contrast=0.08531, elapsed=14.91ms.
# Lag=22, contrast=0.08531, elapsed=15.85ms.
# Lag=23, contrast=0.08531, elapsed=14.45ms.
# Lag=24, contrast=0.08531, elapsed=14.26ms.
# Lag=25, contrast=0.08531, elapsed=14.33ms.
# Lag=26, contrast=0.08531, elapsed=14.29ms.
# Lag=27, contrast=0.08531, elapsed=14.47ms.
# Lag=28, contrast=0.08531, elapsed=14.17ms.
# Lag=29, contrast=0.08531, elapsed=13.99ms.
# Lag=30, contrast=0.06094, elapsed=14.09ms.
# Lag=31, contrast=0.08530, elapsed=14.13ms.
# Lag=32, contrast=0.08530, elapsed=14.12ms.
# Lag=33, contrast=0.08530, elapsed=14.10ms.
# Lag=34, contrast=0.08530, elapsed=15.48ms.
# Lag=35, contrast=0.08530, elapsed=14.56ms.
# Lag=36, contrast=0.08530, elapsed=14.23ms.
# Lag=37, contrast=0.08530, elapsed=14.25ms.
# Lag=38, contrast=0.08530, elapsed=14.20ms.
# Lag=39, contrast=0.08530, elapsed=14.17ms.
# Lag=40, contrast=0.10071, elapsed=14.15ms.
# Lag=41, contrast=0.08855, elapsed=14.18ms.
# Lag=42, contrast=0.08855, elapsed=14.21ms.
# Lag=43, contrast=0.08855, elapsed=14.22ms.
# Lag=44, contrast=0.08855, elapsed=14.32ms.
# Lag=45, contrast=0.08855, elapsed=14.21ms.
# Lag=46, contrast=0.08855, elapsed=14.20ms.
# Lag=47, contrast=0.08855, elapsed=14.19ms.
# Lag=48, contrast=0.08855, elapsed=14.34ms.
# Lag=49, contrast=0.08855, elapsed=14.14ms.
# Lag=50, contrast=0.05466, elapsed=13.90ms.
# Lag=51, contrast=0.07074, elapsed=14.15ms.
# Lag=52, contrast=0.07074, elapsed=14.20ms.
# Lag=53, contrast=0.07074, elapsed=14.73ms.
# Lag=54, contrast=0.07074, elapsed=15.71ms.
# Lag=55, contrast=0.07074, elapsed=14.81ms.
# Lag=56, contrast=0.07074, elapsed=14.24ms.
# Lag=57, contrast=0.07074, elapsed=14.43ms.
# Lag=58, contrast=0.07074, elapsed=14.59ms.
# Lag=59, contrast=0.07074, elapsed=14.44ms.
# Lag=60, contrast=0.06846, elapsed=14.26ms.
# Lag=61, contrast=0.09047, elapsed=14.40ms.
# Lag=62, contrast=0.09047, elapsed=14.21ms.
# Lag=63, contrast=0.09047, elapsed=14.19ms.
# Lag=64, contrast=0.09047, elapsed=14.15ms.
# Lag=65, contrast=0.09047, elapsed=14.22ms.
# Lag=66, contrast=0.09047, elapsed=14.20ms.
# Lag=67, contrast=0.09047, elapsed=15.13ms.
# Lag=68, contrast=0.09047, elapsed=14.36ms.
# Lag=69, contrast=0.09047, elapsed=14.13ms.
# Lag=70, contrast=0.08765, elapsed=15.11ms.
# Lag=71, contrast=0.09166, elapsed=14.93ms.
# Lag=72, contrast=0.09166, elapsed=14.68ms.
# Lag=73, contrast=0.09166, elapsed=14.56ms.
# Lag=74, contrast=0.09166, elapsed=14.38ms.
# Lag=75, contrast=0.09166, elapsed=14.25ms.
# Lag=76, contrast=0.09166, elapsed=14.17ms.
# Lag=77, contrast=0.09166, elapsed=14.21ms.
# Lag=78, contrast=0.09166, elapsed=14.18ms.
# Lag=79, contrast=0.09166, elapsed=14.16ms.
# Lag=80, contrast=0.09065, elapsed=14.14ms.
# Lag=81, contrast=0.11544, elapsed=14.23ms.
# Lag=82, contrast=0.11544, elapsed=14.17ms.
# Lag=83, contrast=0.11544, elapsed=14.20ms.
# Lag=84, contrast=0.11544, elapsed=14.36ms.
# Lag=85, contrast=0.11544, elapsed=14.13ms.
# Lag=86, contrast=0.11544, elapsed=14.38ms.
# Lag=87, contrast=0.11544, elapsed=14.70ms.
# Lag=88, contrast=0.11544, elapsed=14.21ms.
# Lag=89, contrast=0.11544, elapsed=14.53ms.
# Lag=90, contrast=0.10205, elapsed=14.28ms.
# Lag=91, contrast=0.11301, elapsed=14.44ms.
# Lag=92, contrast=0.11301, elapsed=14.39ms.
# Lag=93, contrast=0.11301, elapsed=14.23ms.
# Lag=94, contrast=0.11301, elapsed=14.29ms.
# Lag=95, contrast=0.11301, elapsed=14.27ms.
# Lag=96, contrast=0.11301, elapsed=14.28ms.
# Lag=97, contrast=0.11301, elapsed=14.28ms.
# Lag=98, contrast=0.11301, elapsed=14.29ms.
# Lag=99, contrast=0.11301, elapsed=14.21ms.
# Lag=100, contrast=0.10519, elapsed=14.27ms.
# Lag=101, contrast=0.13084, elapsed=14.56ms.
# Lag=102, contrast=0.13084, elapsed=15.14ms.
# Lag=103, contrast=0.13084, elapsed=14.42ms.
# Lag=104, contrast=0.13084, elapsed=15.65ms.
# Lag=105, contrast=0.13084, elapsed=14.54ms.
# Lag=106, contrast=0.13084, elapsed=14.32ms.
# Lag=107, contrast=0.13084, elapsed=14.40ms.
# Lag=108, contrast=0.13084, elapsed=14.30ms.
# Lag=109, contrast=0.13084, elapsed=14.19ms.
# Lag=110, contrast=0.12119, elapsed=14.16ms.
# Lag=111, contrast=0.13513, elapsed=14.16ms.
# Lag=112, contrast=0.13513, elapsed=14.18ms.
# Lag=113, contrast=0.13513, elapsed=14.16ms.
# Lag=114, contrast=0.13513, elapsed=14.20ms.
# Lag=115, contrast=0.13513, elapsed=14.18ms.
# Lag=116, contrast=0.13513, elapsed=14.33ms.
# Lag=117, contrast=0.13513, elapsed=15.00ms.
# Lag=118, contrast=0.13513, elapsed=14.36ms.
# Lag=119, contrast=0.13513, elapsed=14.02ms.
# Lag=120, contrast=0.11965, elapsed=13.90ms.
# Lag=121, contrast=0.12722, elapsed=14.15ms.
# Lag=122, contrast=0.12722, elapsed=14.72ms.
# Lag=123, contrast=0.12722, elapsed=14.37ms.
# Lag=124, contrast=0.12722, elapsed=14.19ms.
# Lag=125, contrast=0.12722, elapsed=14.21ms.
# Lag=126, contrast=0.12722, elapsed=14.20ms.
# Lag=127, contrast=0.12722, elapsed=14.23ms.
# Lag=128, contrast=0.12722, elapsed=14.17ms.
# Lag=129, contrast=0.12722, elapsed=14.17ms.
# Lag=130, contrast=0.10766, elapsed=14.10ms.
# Lag=131, contrast=0.11787, elapsed=14.38ms.
# Lag=132, contrast=0.11787, elapsed=14.14ms.
# Lag=133, contrast=0.11787, elapsed=13.94ms.
# Lag=134, contrast=0.11787, elapsed=14.44ms.
# Lag=135, contrast=0.11787, elapsed=15.07ms.
# Lag=136, contrast=0.11787, elapsed=14.47ms.
# Lag=137, contrast=0.11787, elapsed=14.24ms.
# Lag=138, contrast=0.11787, elapsed=14.91ms.
# Lag=139, contrast=0.11787, elapsed=14.75ms.
# Lag=140, contrast=0.12630, elapsed=14.31ms.
# Lag=141, contrast=0.15079, elapsed=14.31ms.
# Lag=142, contrast=0.15079, elapsed=14.27ms.
# Lag=143, contrast=0.15079, elapsed=14.22ms.
# Lag=144, contrast=0.15079, elapsed=14.20ms.
# Lag=145, contrast=0.15079, elapsed=14.18ms.
# Lag=146, contrast=0.15079, elapsed=14.11ms.
# Lag=147, contrast=0.15079, elapsed=14.17ms.
# Lag=148, contrast=0.15079, elapsed=14.25ms.
# Lag=149, contrast=0.15079, elapsed=14.15ms.
# Lag=150, contrast=0.14867, elapsed=14.64ms.
# Lag=151, contrast=0.13476, elapsed=14.38ms.
# Lag=152, contrast=0.13476, elapsed=14.32ms.
# Lag=153, contrast=0.13476, elapsed=15.04ms.
# Lag=154, contrast=0.13476, elapsed=14.47ms.
# Lag=155, contrast=0.13476, elapsed=14.61ms.
# Lag=156, contrast=0.13476, elapsed=14.30ms.
# Lag=157, contrast=0.13476, elapsed=14.57ms.
# Lag=158, contrast=0.13476, elapsed=15.27ms.
# Lag=159, contrast=0.13476, elapsed=14.54ms.
# Lag=160, contrast=0.11529, elapsed=15.06ms.
# Lag=161, contrast=0.13766, elapsed=14.70ms.
# Lag=162, contrast=0.13766, elapsed=14.96ms.
# Lag=163, contrast=0.13766, elapsed=14.62ms.
# Lag=164, contrast=0.13766, elapsed=14.62ms.
# Lag=165, contrast=0.13766, elapsed=14.68ms.
# Lag=166, contrast=0.13766, elapsed=15.30ms.
# Lag=167, contrast=0.13766, elapsed=14.43ms.
# Lag=168, contrast=0.13766, elapsed=14.83ms.
# Lag=169, contrast=0.13766, elapsed=14.41ms.
# Lag=170, contrast=0.12619, elapsed=14.13ms.
# Lag=171, contrast=0.15298, elapsed=15.18ms.
# Lag=172, contrast=0.15298, elapsed=14.46ms.
# Lag=173, contrast=0.15298, elapsed=14.17ms.
# Lag=174, contrast=0.15298, elapsed=14.15ms.
# Lag=175, contrast=0.15298, elapsed=14.11ms.
# Lag=176, contrast=0.15298, elapsed=14.10ms.
# Lag=177, contrast=0.15298, elapsed=14.12ms.
# Lag=178, contrast=0.15298, elapsed=14.05ms.
# Lag=179, contrast=0.15298, elapsed=14.07ms.
# Lag=180, contrast=0.14159, elapsed=14.15ms.
# Lag=181, contrast=0.13716, elapsed=14.31ms.
# Lag=182, contrast=0.13716, elapsed=14.28ms.
# Lag=183, contrast=0.13716, elapsed=14.36ms.
# Lag=184, contrast=0.13716, elapsed=15.22ms.
# Lag=185, contrast=0.13716, elapsed=14.75ms.
# Lag=186, contrast=0.13716, elapsed=14.84ms.
# Lag=187, contrast=0.13716, elapsed=15.22ms.
# Lag=188, contrast=0.13716, elapsed=14.36ms.
# Lag=189, contrast=0.13716, elapsed=14.32ms.
# Lag=190, contrast=0.11791, elapsed=14.20ms.
# Lag=191, contrast=0.13848, elapsed=14.23ms.
# Lag=192, contrast=0.13848, elapsed=14.17ms.
# Lag=193, contrast=0.13848, elapsed=14.21ms.
# Lag=194, contrast=0.13848, elapsed=14.21ms.
# Lag=195, contrast=0.13848, elapsed=14.19ms.
# Lag=196, contrast=0.13848, elapsed=14.17ms.
# Lag=197, contrast=0.13848, elapsed=14.54ms.
# Lag=198, contrast=0.13848, elapsed=14.60ms.
# Lag=199, contrast=0.13848, elapsed=14.86ms.
# Lag=200, contrast=0.13486, elapsed=14.39ms.
# Lag=201, contrast=0.12562, elapsed=14.15ms.
# Lag=202, contrast=0.12562, elapsed=14.01ms.
# Lag=203, contrast=0.12562, elapsed=14.21ms.
# Lag=204, contrast=0.12562, elapsed=14.77ms.
# Lag=205, contrast=0.12562, elapsed=14.66ms.
# Lag=206, contrast=0.12562, elapsed=14.65ms.
# Lag=207, contrast=0.12562, elapsed=14.30ms.
# Lag=208, contrast=0.12562, elapsed=14.15ms.
# Lag=209, contrast=0.12562, elapsed=14.25ms.
# Lag=210, contrast=0.11333, elapsed=14.24ms.
# Lag=211, contrast=0.12336, elapsed=14.15ms.
# Lag=212, contrast=0.12336, elapsed=14.16ms.
# Lag=213, contrast=0.12336, elapsed=14.23ms.
# Lag=214, contrast=0.12336, elapsed=14.30ms.
# Lag=215, contrast=0.12336, elapsed=14.18ms.
# Lag=216, contrast=0.12336, elapsed=15.08ms.
# Lag=217, contrast=0.12336, elapsed=14.34ms.
# Lag=218, contrast=0.12336, elapsed=14.32ms.
# Lag=219, contrast=0.12336, elapsed=14.83ms.
# Lag=220, contrast=0.11845, elapsed=14.43ms.
# Lag=221, contrast=0.12126, elapsed=14.26ms.
# Lag=222, contrast=0.12126, elapsed=14.14ms.
# Lag=223, contrast=0.12126, elapsed=14.22ms.
# Lag=224, contrast=0.12126, elapsed=14.14ms.
# Lag=225, contrast=0.12126, elapsed=14.19ms.
# Lag=226, contrast=0.12126, elapsed=14.10ms.
# Lag=227, contrast=0.12126, elapsed=14.18ms.
# Lag=228, contrast=0.12126, elapsed=14.19ms.
# Lag=229, contrast=0.12126, elapsed=14.05ms.
# Lag=230, contrast=0.10215, elapsed=14.49ms.
# Lag=231, contrast=0.10435, elapsed=14.45ms.
# Lag=232, contrast=0.10435, elapsed=14.45ms.
# Lag=233, contrast=0.10435, elapsed=16.92ms.
# Lag=234, contrast=0.10435, elapsed=14.80ms.
# Lag=235, contrast=0.10435, elapsed=14.27ms.
# Lag=236, contrast=0.10435, elapsed=14.08ms.
# Lag=237, contrast=0.10435, elapsed=14.75ms.
# Lag=238, contrast=0.10435, elapsed=15.12ms.
# Lag=239, contrast=0.10435, elapsed=14.31ms.
# Lag=240, contrast=0.08905, elapsed=14.08ms.
# Lag=241, contrast=0.09779, elapsed=14.34ms.
# Lag=242, contrast=0.09779, elapsed=14.28ms.
# Lag=243, contrast=0.09779, elapsed=14.66ms.
# Lag=244, contrast=0.09779, elapsed=14.25ms.
# Lag=245, contrast=0.09779, elapsed=14.30ms.
# Lag=246, contrast=0.09779, elapsed=14.33ms.
# Lag=247, contrast=0.09779, elapsed=14.45ms.
# Lag=248, contrast=0.09779, elapsed=15.28ms.
# Lag=249, contrast=0.09779, elapsed=14.97ms.
# Lag=250, contrast=0.09845, elapsed=14.52ms.
# Lag=251, contrast=0.07868, elapsed=14.37ms.
# Lag=252, contrast=0.07868, elapsed=14.13ms.
# Lag=253, contrast=0.07868, elapsed=14.05ms.
# Lag=254, contrast=0.07868, elapsed=14.30ms.
# Lag=255, contrast=0.07868, elapsed=14.73ms.
# Lag=256, contrast=0.07868, elapsed=14.66ms.
# Lag=257, contrast=0.07868, elapsed=14.18ms.
# Lag=258, contrast=0.07868, elapsed=14.13ms.
# Lag=259, contrast=0.07868, elapsed=14.37ms.
# Lag=260, contrast=0.04636, elapsed=14.17ms.
# Lag=261, contrast=0.07602, elapsed=14.19ms.
# Lag=262, contrast=0.07602, elapsed=14.20ms.
# Lag=263, contrast=0.07602, elapsed=14.15ms.
# Lag=264, contrast=0.07602, elapsed=14.39ms.
# Lag=265, contrast=0.07602, elapsed=14.92ms.
# Lag=266, contrast=0.07602, elapsed=14.71ms.
# Lag=267, contrast=0.07602, elapsed=14.14ms.
# Lag=268, contrast=0.07602, elapsed=14.10ms.
# Lag=269, contrast=0.07602, elapsed=14.29ms.
# Lag=270, contrast=0.08465, elapsed=14.44ms.
# Lag=271, contrast=0.06588, elapsed=14.68ms.
# Lag=272, contrast=0.06588, elapsed=14.84ms.
# Lag=273, contrast=0.06588, elapsed=14.33ms.
# Lag=274, contrast=0.06588, elapsed=14.12ms.
# Lag=275, contrast=0.06588, elapsed=14.35ms.
# Lag=276, contrast=0.06588, elapsed=14.21ms.
# Lag=277, contrast=0.06588, elapsed=14.29ms.
# Lag=278, contrast=0.06588, elapsed=14.16ms.
# Lag=279, contrast=0.06588, elapsed=14.32ms.
# Lag=280, contrast=0.04953, elapsed=14.04ms.
# Lag=281, contrast=0.06859, elapsed=15.01ms.
# Lag=282, contrast=0.06859, elapsed=14.23ms.
# Lag=283, contrast=0.06859, elapsed=14.46ms.
# Lag=284, contrast=0.06859, elapsed=14.82ms.
# Lag=285, contrast=0.06859, elapsed=14.24ms.
# Lag=286, contrast=0.06859, elapsed=14.49ms.
# Lag=287, contrast=0.06859, elapsed=14.32ms.
# Lag=288, contrast=0.06859, elapsed=13.92ms.
# Lag=289, contrast=0.06859, elapsed=14.17ms.
# Lag=290, contrast=0.05739, elapsed=14.83ms.
# Lag=291, contrast=0.04296, elapsed=15.50ms.
# Lag=292, contrast=0.04296, elapsed=14.69ms.
# Lag=293, contrast=0.04296, elapsed=14.14ms.
# Lag=294, contrast=0.04296, elapsed=14.14ms.
# Lag=295, contrast=0.04296, elapsed=14.27ms.
# Lag=296, contrast=0.04296, elapsed=14.31ms.
# Lag=297, contrast=0.04296, elapsed=14.08ms.
# Lag=298, contrast=0.04296, elapsed=14.19ms.
# Lag=299, contrast=0.04296, elapsed=14.97ms.
# Lag=300, contrast=0.03044, elapsed=14.94ms.

# %%
print(f'Estimated lag: {ll.lead_lag} seconds (bitflyer leading).')
# Out:
# Estimated lag: 17.1 seconds (bitflyer leading).

# %%
print(f'Positive lag means TS1 is leading. LLR: {ll.llr:.2f} (cf. paper for the definition of LLR).')
# Out:
# Positive lag means TS1 is leading. LLR: 5.02 (cf. paper for the definition of LLR).

# %%
ll.plot_results()
